# %% [markdown]
# Open your file directory then open the powershall command prompt on it.
#
# command: pip install numpy

# %% [markdown]
# ### Check Numpy Version

# %%
import numpy as np

print(np.__version__)
# Out:
# 1.21.5

# %%
values = [2, 5, 9, 6, 1, 7, 4, 3, 1]

# since we have declared numpy as np in the previous code.
# so we don't need to import numpy again.
x = np.array(values)
print(x)
# Out:
# [2 5 9 6 1 7 4 3 1]
